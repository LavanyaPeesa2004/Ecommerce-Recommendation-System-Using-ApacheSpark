# %%
gold_df = spark.table("gold_interaction_matrix")
silver_df = spark.table("silver_customer_products")

# %%
gold_df.select("user_id").distinct().show(20)
# Out:
# +-------+
# |user_id|
# +-------+
# |  72738|
# |   5103|
# | 158156|
# | 180905|
# |  29091|
# |  53003|
# |  13031|
# |  26268|
# |  77371|
# | 114675|
# | 195500|
# | 182316|
# |  28675|
# |  17169|
# | 116610|
# | 199774|
# |  23799|
# | 147204|
# |  97395|
# |  88007|
# +-------+
# only showing top 20 rows

# %%
purchased = (

    silver_df

    .filter(silver_df.user_id==user_id)

    .select("product_id","product_name")

    .distinct()

)

display(purchased)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th></tr></thead><tbody><tr><td>25256</td><td>Cultured Low Fat Buttermilk</td></tr><tr><td>13780</td><td>Thyme</td></tr><tr><td>7948</td><td>Organic Unsalted Butter</td></tr><tr><td>13854</td><td>Ylang Ylang + Cedarwood Hand Soap</td></tr><tr><td>27521</td><td>Organic Lacinato (Dinosaur) Kale</td></tr><tr><td>18531</td><td>Organic Heavy Whipping Cream</td></tr><tr><td>46667</td><td>Organic Ginger Root</td></tr><tr><td>14992</td><td>Green Beans</td></tr><tr><td>45223</td><td>Just Green Unsweetened Tea</td></tr><tr><td>44359</td><td>Organic Small Bunch Celery</td></tr><tr><td>2314</td><td>Whole Milk Ricotta Cheese</td></tr><tr><td>24221</td><td>Organic Red Grapes</td></tr><tr><td>322</td><td>Brooklyn Pizza Dough</td></tr><tr><td>45345</td><td>Spearmint + Lemongrass Hand Soap</td></tr><tr><td>33754</td><td>Total 2% with Strawberry Lowfat Greek Strained Yogurt</td></tr><tr><td>37065</td><td>Serrano Chile Peppers</td></tr><tr><td>23537</td><td>Light Brown Sugar</td></tr><tr><td>35939</td><td>Organic Jalapeno Pepper</td></tr><tr><td>34262</td><td>Hint Of Sea Salt Almond Nut Thins</td></tr><tr><td>16797</td><td>Strawberries</td></tr><tr><td>37158</td><td>Chicken & Maple Breakfast Sausage</td></tr><tr><td>24852</td><td>Banana</td></tr><tr><td>21137</td><td>Organic Strawberries</td></tr><tr><td>27304</td><td>Organic 5 Grain Elbows & White Cheddar Macaroni and Cheese</td></tr><tr><td>2091</td><td>Almond Nut & Rice Cracker Snacks</td></tr><tr><td>1511</td><td>2% Reduced Fat DHA Omega-3 Reduced Fat Milk</td></tr><tr><td>41290</td><td>Lemonade</td></tr><tr><td>38996</td><td>Grape Tomatoes</td></tr><tr><td>39984</td><td>Organic Dill</td></tr><tr><td>14688</td><td>Bamboo Skewers</td></tr><tr><td>810</td><td>Organic Honey Mustard</td></tr><tr><td>7051</td><td>Happy Tot Banana, Peach, Prune & Coconut Organic Superfoods</td></tr><tr><td>38689</td><td>Organic Reduced Fat Milk</td></tr><tr><td>30480</td><td>Tomatoes, Whole Peeled</td></tr><tr><td>4920</td><td>Seedless Red Grapes</td></tr><tr><td>49401</td><td>Chicken Base, Organic</td></tr><tr><td>33787</td><td>Total 2% Lowfat Greek Strained Yogurt with Peach</td></tr><tr><td>5205</td><td>Tamarind Stir-Fry Paste</td></tr><tr><td>15040</td><td>Organic Acorn Squash</td></tr><tr><td>4957</td><td>Total 2% Lowfat Greek Strained Yogurt With Blueberry</td></tr><tr><td>25435</td><td>Original Lemonade</td></tr><tr><td>28593</td><td>Reduced Fat 2% Chocolate Milk</td></tr><tr><td>5025</td><td>Green Onions</td></tr><tr><td>41757</td><td>Organic Air Chilled Whole Chicken</td></tr><tr><td>13190</td><td>Medium Egg Noodles</td></tr><tr><td>18656</td><td>Organic Red Potato</td></tr><tr><td>48745</td><td>Globe Eggplant</td></tr><tr><td>43961</td><td>Organic Peeled Whole Baby Carrots</td></tr><tr><td>12461</td><td>Pain Relief, Gel, Value Size</td></tr><tr><td>18094</td><td>Organic Creamy Deluxe Macaroni Dinner Rotini & White Cheddar Sauce</td></tr><tr><td>11408</td><td>Crushed Tomatoes</td></tr><tr><td>26209</td><td>Limes</td></tr><tr><td>44014</td><td>Authentic Red Curry Paste</td></tr><tr><td>40256</td><td>Cinnamon Sticks</td></tr><tr><td>8277</td><td>Apple Honeycrisp Organic</td></tr><tr><td>45066</td><td>Honeycrisp Apple</td></tr><tr><td>27695</td><td>Natural Chicken & Sage Breakfast Sausage</td></tr><tr><td>24891</td><td>Organic Chocolate 1% Milk with DHA Omega-3</td></tr><tr><td>32320</td><td>Chicken Thigh</td></tr><tr><td>34126</td><td>Organic Italian Parsley Bunch</td></tr><tr><td>39877</td><td>Organic Granny Smith Apple</td></tr><tr><td>16759</td><td>Organic Carrot Bunch</td></tr><tr><td>22935</td><td>Organic Yellow Onion</td></tr><tr><td>34590</td><td>Pitted Dates</td></tr><tr><td>41055</td><td>Organic Red Wine Vineger</td></tr><tr><td>31717</td><td>Organic Cilantro</td></tr><tr><td>13304</td><td>Whole Peeled Tomatoes</td></tr><tr><td>20114</td><td>Jalapeno ...

# %%
products_df = spark.table("bronze_products")

products_df.show(5)
# Out:
# +----------+--------------------+--------+-------------+
# |product_id|        product_name|aisle_id|department_id|
# +----------+--------------------+--------+-------------+
# |         1|Chocolate Sandwic...|      61|           19|
# |         2|    All-Seasons Salt|     104|           13|
# |         3|Robust Golden Uns...|      94|            7|
# |         4|Smart Ones Classi...|      38|            1|
# |         5|Green Chile Anyti...|       5|           13|
# +----------+--------------------+--------+-------------+
# only showing top 5 rows

# %%
candidate_products = products_df.select("product_id")

candidate_products.show(5)
# Out:
# +----------+
# |product_id|
# +----------+
# |         1|
# |         2|
# |         3|
# |         4|
# |         5|
# +----------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import lit

user_products = (
    candidate_products
    .withColumn("user_id", lit(user_id))
)

display(user_products.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>user_id</th></tr></thead><tbody><tr><td>1</td><td>72738</td></tr><tr><td>2</td><td>72738</td></tr><tr><td>3</td><td>72738</td></tr><tr><td>4</td><td>72738</td></tr><tr><td>5</td><td>72738</td></tr></tbody></table></div>

# %%
pred = als__model.transform(user_products)

display(pred.limit(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8411869437893490>, line 1
# ----> 1 pred = als__model.transform(user_products)
#       3 display(pred.limit(10))
#
# NameError: name 'als__model' is not defined
